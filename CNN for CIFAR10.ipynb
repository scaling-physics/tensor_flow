# %%
# import tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
# additional imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print("x_train.shape:", x_train.shape)
print("y_train.shape", y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# x_train.shape: (50000, 32, 32, 3)
# y_train.shape (50000,)

# %%
# number of classes
K = len(set(y_train))
print("number of classes:", K)
# Out:
# number of classes: 10

# %%
# Build the model using the functional API
i = Input(shape=x_train[0].shape)
# x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
# x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
# x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.2)(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.2)(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.2)(x)

# x = GlobalMaxPooling2D()(x)
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %%
# Compile
# Note: make sure you are using the GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Fit
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 20s 9ms/step - loss: 1.2941 - accuracy: 0.5546 - val_loss: 0.8856 - val_accuracy: 0.6924
# Epoch 2/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8374 - accuracy: 0.7118 - val_loss: 0.7732 - val_accuracy: 0.7359
# Epoch 3/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.6809 - accuracy: 0.7648 - val_loss: 0.6661 - val_accuracy: 0.7761
# Epoch 4/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5784 - accuracy: 0.8006 - val_loss: 0.6543 - val_accuracy: 0.7853
# Epoch 5/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.4852 - accuracy: 0.8344 - val_loss: 0.6293 - val_accuracy: 0.7901
# Epoch 6/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.4160 - accuracy: 0.8542 - val_loss: 0.7214 - val_accuracy: 0.7773
# Epoch 7/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.3482 - accuracy: 0.8800 - val_loss: 0.5918 - val_accuracy: 0.8184
# Epoch 8/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2956 - accuracy: 0.8980 - val_loss: 0.6464 - val_accuracy: 0.8036
# Epoch 9/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2580 - accuracy: 0.9104 - val_loss: 0.6293 - val_accuracy: 0.8147
# Epoch 10/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.2229 - accuracy: 0.9241 - val_loss: 0.7500 - val_accuracy: 0.8080
# Epoch 11/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1964 - accuracy: 0.9327 - val_loss: 0.6689 - val_accuracy: 0.8167
# Epoch 12/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1701 - accuracy: 0.9422 - val_loss: 0.6891 - val_accuracy: 0.8265
# Epoch 13/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1530 - accuracy: 0.9473 - val_loss: 0.6338 - val_accuracy: 0.8404
# Epoch 14/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1450 - accuracy: 0.9508 - val_loss: 0.7330 - val_accuracy: 0.8357
# Epoch 15/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1296 - accuracy: 0.9554 - val_loss: 0.7577 - val_accuracy: 0.8217
# Epoch 16/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1213 - accuracy: 0.9598 - val_loss: 0.7297 - val_accuracy: 0.8312
# Epoch 17/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1069 - accuracy: 0.9646 - val_loss: 0.7091 - val_accuracy: 0.8326
# Epoch 18/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1105 - accuracy: 0.9624 - val_loss: 0.7368 - val_accuracy: 0.8299
# Epoch 19/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.1009 - accuracy: 0.9673 - val_loss: 0.7246 - val_accuracy: 0.8214
# Epoch 20/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0970 - accuracy: 0.9672 - val_loss: 0.7744 - val_accuracy: 0.8253
# Epoch 21/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0922 - accuracy: 0.9688 - val_loss: 0.8234 - val_accuracy: 0.8270
# Epoch 22/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0845 - accuracy: 0.9722 - val_loss: 0.7665 - val_accuracy: 0.8343
# Epoch 23/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0803 - accuracy: 0.9737 - val_loss: 0.7092 - val_accuracy: 0.8357
# Epoch 24/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0802 - accuracy: 0.9741 - val_loss: 0.7176 - val_accuracy: 0.8356
# Epoch 25/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0762 - accuracy: 0.9751 - val_loss: 0.8193 - val_accuracy: 0.8282
# Epoch 26/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0709 - accuracy: 0.9772 - val_loss: 0.8035 - val_accuracy: 0.8295
# Epoch 27/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0702 - accuracy: 0.9770 - val_loss: 0.8576 - val_accuracy: 0.8276
# Epoch 28/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0650 - accuracy: 0.9793 - val_loss: 0.7604 - val_accuracy: 0.8450
# Epoch 29/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0660 - accuracy: 0.9788 - val_loss: 0.8122 - val_accuracy: 0.8417
# Epoch 30/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0610 - accuracy: 0.9798 - val_loss: 0.7537 - val_accuracy: 0.8427
# Epoch 31/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0598 - accuracy: 0.9801 - val_loss: 0.7837 - val_accuracy: 0.8411
# Epoch 32/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0569 - accuracy: 0.9811 - val_loss: 0.7694 - val_accuracy: 0.8385
# Epoch 33/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0569 - accuracy: 0.9817 - val_loss: 0.8258 - val_accuracy: 0.8403
# Epoch 34/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0560 - accuracy: 0.9822 - val_loss: 0.9139 - val_accuracy: 0.8322
# Epoch 35/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0592 - accuracy: 0.9809 - val_loss: 0.7685 - val_accuracy: 0.8360
# Epoch 36/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0508 - accuracy: 0.9834 - val_loss: 0.8395 - val_accuracy: 0.8380
# Epoch 37/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0523 - accuracy: 0.9826 - val_loss: 0.8009 - val_accuracy: 0.8428
# Epoch 38/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0496 - accuracy: 0.9842 - val_loss: 0.7697 - val_accuracy: 0.8341
# Epoch 39/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0496 - accuracy: 0.9835 - val_loss: 0.7789 - val_accuracy: 0.8382
# Epoch 40/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0480 - accuracy: 0.9845 - val_loss: 0.8237 - val_accuracy: 0.8459
# Epoch 41/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0485 - accuracy: 0.9844 - val_loss: 0.8033 - val_accuracy: 0.8491
# Epoch 42/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0445 - accuracy: 0.9858 - val_loss: 0.8742 - val_accuracy: 0.8423
# Epoch 43/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0465 - accuracy: 0.9854 - val_loss: 0.8554 - val_accuracy: 0.8446
# Epoch 44/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0422 - accuracy: 0.9860 - val_loss: 0.8500 - val_accuracy: 0.8461
# Epoch 45/50
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.0441 - accuracy: 0.9857 - val_loss: 0.8693 - val_accuracy: 0.8411
# Epoch 46/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0441 - accuracy: 0.9862 - val_loss: 0.8258 - val_accuracy: 0.8431
# Epoch 47/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0446 - accuracy: 0.9862 - val_loss: 0.8678 - val_accuracy: 0.8437
# Epoch 48/50
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 0.8882 - val_accuracy: 0.8409
# Epoch 49/50
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.0406 - accuracy: 0.9868 - val_loss: 0.8495 - val_accuracy: 0.8423
# Epoch 50/50
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.0436 - accuracy: 0.9867 - val_loss: 0.9443 - val_accuracy: 0.8297

# %%
# Fit with data augmentation
# Note: if you run this AFTER calling the previous model.fit(), it will CONTINUE training where it left off
batch_size = 32
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size
r = model.fit(train_generator, validation_data=(x_test, y_test), steps_per_epoch=steps_per_epoch, epochs=15)
# Out:
# Epoch 1/15
# 1055/1562 [===================>..........] - ETA: 14s - loss: 0.5721 - accuracy: 0.8192

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()


p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Confusion matrix, without normalization
# [[861  10  38  19  14   3  10   8  25  12]
#  [  6 936   5   6   2   0   7   0  15  23]
#  [ 46   1 744  55  56  21  57  13   6   1]
#  [ 13   2  50 724  49  77  63  19   2   1]
#  [ 10   0  36  36 834  16  35  31   2   0]
#  [  3   3  40 169  39 693  24  26   2   1]
#  [  3   1  21  44   9   4 910   5   3   0]
#  [  7   4  11  36  49  24  13 853   1   2]
#  [ 38  18  12  10   7   2   9   2 891  11]
#  [ 18  69   7  11   5  11   9   4  15 851]]

# %%
# label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
# Show some misclassified examples
# TODO: add label names
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]));
